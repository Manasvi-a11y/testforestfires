# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv('weight-height.csv')

# %%
df.head()
# Out:
#   Gender     Height      Weight
# 0   Male  73.847017  241.893563
# 1   Male  68.781904  162.310473
# 2   Male  74.110105  212.740856
# 3   Male  71.730978  220.042470
# 4   Male  69.881796  206.349801

# %%
##scatter plot
plt.scatter(df['Weight'],df['Height'])
plt.xlabel('Weight')
plt.ylabel('Height')
# Out:
# Text(0, 0.5, 'Height')

# %%
import seaborn as sns
sns.pairplot(df)

# %%
df.head()
# Out:
#   Gender     Height      Weight
# 0   Male  73.847017  241.893563
# 1   Male  68.781904  162.310473
# 2   Male  74.110105  212.740856
# 3   Male  71.730978  220.042470
# 4   Male  69.881796  206.349801

# %%
X=df[['Weight']]
np.array(X).shape
# Out:
# (10000, 1)

# %%
X=df[['Weight']]
y=df['Weight']

# %%
X_series=df['Weight']
np.array(X_series).shape
# Out:
# (10000,)

# %%
y
# Out:
# 0       241.893563
# 1       162.310473
# 2       212.740856
# 3       220.042470
# 4       206.349801
#            ...
# 9995    136.777454
# 9996    170.867906
# 9997    128.475319
# 9998    163.852461
# 9999    113.649103
# Name: Weight, Length: 10000, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.25,random_state=42)

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()
X_train=scaler.fit_transform(X_train)

# %%
X_test=scaler.transform(X_test)
# Out:
# c:\Data Analyst Bootcamp\venv\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
X_test
# Out:
# array([[-5.02349252],
#        [-5.00199186],
#        [-5.02631916],
#        ...,
#        [-5.07152706],
#        [-5.03109064],
#        [-5.03325268]])

# %%
## Apply Linear Regression
from sklearn.linear_model import LinearRegression

# %%
regression= LinearRegression(n_jobs=-1)

# %%
regression=LinearRegression()

# %%
regression.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
regression.coef_
# Out:
# array([32.02146706])

# %%
print("Coefficient or slope :",regression.coef_)
print("Intercept :",regression.intercept_)
# Out:
# Coefficient or slope : [32.02146706]
# Intercept : 161.23075926386

# %%
## plot training data plot best fit line
plt.scatter(X_train,y_train)
plt.plot(X_train,regression.predict(X_train))

# %%
predicted height output = intercept + coef_(Weights)
y_pred_test = 191.230 + 32.201(X_test)
# Out:
#   Cell In[89], line 1
#     predicted height output = intercept + coef_(Weights)
#               ^
# SyntaxError: invalid syntax

# %%
##prediction for test data
y_pred=regression.predict(X_test)

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error

# %%
mse=mean_squared_error(y_test,y_pred)
mae=mean_absolute_error(y_test,y_pred)
rmse=np.sqrt(mse)
print(mse)
print(mae)
print(rmse)
# Out:
# 27240.311246597867
# 162.04296741010901
# 165.04639119531777

# %%
from sklearn.metrics import r2_score

# %%
score=r2_score(y_test,y_pred)
print(score)
# Out:
# -25.02383215155035

# %%
1-(1-score)*(len(y_test)-1)/(len(y_test)-X_test.shape[1]-1)
# Out:
# -25.034250018704697

# %%
import statsmodels.api as sm
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[105], line 1
# ----> 1 import statsmodels.api as sm
#
# ModuleNotFoundError: No module named 'statsmodels'

# %%
model=sm.OLS(y_train,X_train).fit()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[107], line 1
# ----> 1 model=sm.OLS(y_train,X_train).fit()
#
# NameError: name 'sm' is not defined

# %%
## prediction for new data
regression.predict(scaler.transform[[72]])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[108], line 2
#       1 ## prediction for new data
# ----> 2 regression.predict(scaler.transform[[72]])
#
# TypeError: 'method' object is not subscriptable
